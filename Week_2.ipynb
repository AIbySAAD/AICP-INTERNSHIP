# %% [markdown]
# FROM: SAAD ZAHOOR ,
# UNIVERSITY: FOUNDATION UNIVERSITY

# %%
# importing packages and modules here:
import pandas as pd

# %% [markdown]
# Question 1
# ---

# %% [markdown]
# Writer pandas series code to get following output without using dictionary:

# %%
label_indices=['a','x','c','2','e']  # indices label we are going to assign
values=[1,4,9,6,7] # values we are going to pass the series
df= pd.Series(values,label_indices)  # pandas has a function for creating a series in which we pass the values and labels
df
# Out:
# a    1
# x    4
# c    9
# 2    6
# e    7
# dtype: int64

# %% [markdown]
# Question 2
# ---

# %% [markdown]
# Writer pandas series code to get following output using dictionary:

# %%
dictionary={'Bilal':42,'Ayesha':38,'Hadia':39}  # create a dictionary
df=pd.Series(dictionary) # use the pandas Series function to create the series
df
# Out:
# Bilal     42
# Ayesha    38
# Hadia     39
# dtype: int64

# %% [markdown]
# Question 3
# ---

# %% [markdown]
#  Write pandas dataframe code to get following output using python dictionary

# %%
# creating our dictionary
dictionary={'day':['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
            'temperature':[32,35,28,24,32,31],
            'windspeed':[6,7,2,7,4,2],
            'event':['rain','sunny','snow','snow','rain','sunny']}

df=pd.DataFrame(dictionary)  # this function convert the dictionary with vector values into a data frame
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   rain
# 1  1/2/2017           35          7  sunny
# 2  1/3/2017           28          2   snow
# 3  1/4/2017           24          7   snow
# 4  1/5/2017           32          4   rain
# 5  1/6/2017           31          2  sunny

# %% [markdown]
# Question 4
# ---

# %% [markdown]
#  In extension to above question, you are required to replace index by ['a','b','c','d','e','f']

# %%
indecis=['a','b','c','d','e','f']
df=pd.DataFrame(dictionary,index=indecis)  # change the parameter the index of our own choice
df
# Out:
#         day  temperature  windspeed  event
# a  1/1/2017           32          6   rain
# b  1/2/2017           35          7  sunny
# c  1/3/2017           28          2   snow
# d  1/4/2017           24          7   snow
# e  1/5/2017           32          4   rain
# f  1/6/2017           31          2  sunny

# %% [markdown]
# Question 5
# ---

# %% [markdown]
#  In extension to above Q.3, calculate mean, miximum and minimum for label “temperature”

# %%
mean=df['temperature'].mean()
maximum=df['temperature'].max()
minimum=df['temperature'].min()
print('Mean of temprerature is: ',mean)
print('Maximum of label temperature is: ',maximum)
print('Minimum of label temperature is: ',minimum)
# Out:
# Mean of temprerature is:  30.333333333333332
# Maximum of label temperature is:  35
# Minimum of label temperature is:  24

# %% [markdown]
# Question 6
# ---

# %% [markdown]
# Import CSV ‘people.csv’ in the given folder. Keep in mind the following instructions:
# You’re required to import only specific columns ["First Name", "Sex", "Email", “Phone”, “Job Title”]
# Set the following columns ["Sex", "Job Title"] as index columns
# Skip following rows [1,5]
# Export the CSV as “NewPeople.csv”

# %%
df=pd.read_csv('people.csv')  # importing our csv file
df
# Out:
#     Index          User Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    Male
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    Male
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1        bethany14@example.com       214.112.6044x4913    1910-03-24
# 2        bthompson@example.com            277.609.7938    1992-07-02
# ...

# %%
# columns we only want to import
file_path='/content/people.csv'  # specifying our path
selected_col=["First Name", "Sex", "Email", "Phone", "Job Title"]
df=pd.read_csv(file_path,usecols=selected_col)
df
# Out:
#    First Name     Sex                       Email                   Phone  \
# 0      Shelby    Male        elijah57@example.net  001-084-906-7849x73518
# 1     Phillip  Female       bethany14@example.com       214.112.6044x4913
# 2    Kristine    Male       bthompson@example.com            277.609.7938
# 3     Yesenia    Male   kaitlinkaiser@example.com            584.094.6111
# 4        Lori    Male  buchananmanuel@example.net       689-207-3558x7233
# ..        ...     ...                         ...                     ...
# 95     Dennis  Female         bmartin@example.org    001-095-524-2112x257
# 96      Steve  Female       latasha46@example.net        001-865-478-5157
# 97     Wesley    Male        regina11@example.org      995-542-3004x76800
# 98     Summer  Female  alexiscantrell@example.org    001-273-685-6932x092
# 99     Mariah    Male       pcopeland@example.org     (341)594-6554x44657
#
#                 Job Title
# 0         Games developer
# ...

# %%
# using indices of our choice:
col=["Sex", "Job Title"]
df=pd.read_csv(file_path,usecols=selected_col,index_col=col)
df
# Out:
#                              First Name                       Email  \
# Sex    Job Title
# Male   Games developer           Shelby        elijah57@example.net
# Female Phytotherapist           Phillip       bethany14@example.com
# Male   Homeopath               Kristine       bthompson@example.com
#        Market researcher        Yesenia   kaitlinkaiser@example.com
#        Veterinary surgeon          Lori  buchananmanuel@example.net
# ...                                 ...                         ...
# Female Software engineer         Dennis         bmartin@example.org
#        Barrister                  Steve       latasha46@example.net
# Male   Police officer            Wesley        regina11@example.org
# Female Broadcast journalist      Summer  alexiscantrell@example.org
# Male   IT sales professional     Mariah       pcopeland@example.org
#
#                                                Phone
# Sex    Job Title
# Male   Games developer        001-084-906-7849x73518
# ...

# %%
# skip the specific rows
r_to_skip=[1,5]
df=pd.read_csv(file_path,usecols=selected_col,index_col=col,skiprows=r_to_skip)
df
# Out:
#                                 First Name                       Email  \
# Sex    Job Title
# Female Phytotherapist              Phillip       bethany14@example.com
# Male   Homeopath                  Kristine       bthompson@example.com
#        Market researcher           Yesenia   kaitlinkaiser@example.com
#        Waste management officer       Erin         tconner@example.org
# Female Intelligence analyst      Katherine     conniecowan@example.com
# ...                                    ...                         ...
#        Software engineer            Dennis         bmartin@example.org
#        Barrister                     Steve       latasha46@example.net
# Male   Police officer               Wesley        regina11@example.org
# Female Broadcast journalist         Summer  alexiscantrell@example.org
# Male   IT sales professional        Mariah       pcopeland@example.org
#
#                                                  Phone
# Sex    Job Title
# ...

# %%
# Exporting the csv
path='NewPeople.csv'
df.to_csv(path)

# %% [markdown]
# Question 7
# ---

# %% [markdown]
# Import excel sheet ‘SampleWork.xlsx’ in the given folder. Keep in mind the following instructions:
# Import sheet 1
# Import only first and last column from sheet 1
# Skip row 2 while importing the sheet
# Set row 2 as header
# export as new sheet.

# %%
# reading the file
df=pd.read_excel('/content/SampleWork.xlsx')
df
# Out:
#      Name  Age   Stream  Percentage
# 0    Amir   18     Math          95
# 1   Bilal   19  Science          90
# 2  Sufyan   20  Comerce          85
# 3   Saiqa   18     Math          80
# 4   Aimen   32  Science          75

# %%
# Import sheet 1
df=pd.read_excel('/content/SampleWork.xlsx',sheet_name=1)
df
# Out:
#      Name  Age   Stream  Percentage
# 0   Bilal   18     Math          95
# 1   Haiqa   19  Science          90
# 2  Mohsin   20  Comerce          85
# 3   Sonia   18     Math          80
# 4  Sameer   32  Science          75

# %%
# Import only first and last column from sheet 1
df=pd.read_excel('/content/SampleWork.xlsx',sheet_name=1,usecols=[0,3])
df
# Out:
#      Name  Percentage
# 0   Bilal          95
# 1   Haiqa          90
# 2  Mohsin          85
# 3   Sonia          80
# 4  Sameer          75

# %%
# skip row 2
df=pd.read_excel('/content/SampleWork.xlsx',sheet_name=1,usecols=[0,3],skiprows=[2])
df
# Out:
#      Name  Percentage
# 0   Bilal          95
# 1  Mohsin          85
# 2   Sonia          80
# 3  Sameer          75

# %%
# making row 2 as header
df=pd.read_excel('/content/SampleWork.xlsx',sheet_name=1,header=2,usecols=[0,3],skiprows=[2])
df
# Out:
#    Mohsin  85
# 0   Sonia  80
# 1  Sameer  75

# %%
# exporting new sheet
df.to_excel('new sheet.xlsx')

# %% [markdown]
# Question 8
# ---

# %% [markdown]
#  Create the following dataframe as AICP_DF then implement different operations as described below:
# select 'Name', 'Qualification' coloumns and save to df1
# add a new column to AICP_DF “Height” with the following values: [5.1, 6.2, 5.1, 5.2,5.1]
# set column “Name” as the index column.
# retrieve row with index “Hifza”
# retrieve row with index 3
# drop row with index “Bilal”

# %%
# creating data frame
data_frame={'Name':['Sonia','Bilal','Hifza','Kabir','Jazim'],
            'Age':[27,24,22,32,23],
            'Address':['Lahore','Karachi','Sialkot','peshawar','lhr'],
            'Qualification':['Msc','MA','MCA','Phd','bsc']}
df=pd.DataFrame(data_frame)
df
# Out:
#     Name  Age   Address Qualification
# 0  Sonia   27    Lahore           Msc
# 1  Bilal   24   Karachi            MA
# 2  Hifza   22   Sialkot           MCA
# 3  Kabir   32  peshawar           Phd
# 4  Jazim   23       lhr           bsc

# %%
# saving the name column to df1
df1=df.loc[:,['Name','Qualification']] # use the loc function of pandas to do that
df1
# Out:
#     Name Qualification
# 0  Sonia           Msc
# 1  Bilal            MA
# 2  Hifza           MCA
# 3  Kabir           Phd
# 4  Jazim           bsc

# %%
# Adding new column
df['Height']= [5.1, 6.2, 5.1, 5.2,5.1]
df
# Out:
#     Name  Age   Address Qualification  Height
# 0  Sonia   27    Lahore           Msc     5.1
# 1  Bilal   24   Karachi            MA     6.2
# 2  Hifza   22   Sialkot           MCA     5.1
# 3  Kabir   32  peshawar           Phd     5.2
# 4  Jazim   23       lhr           bsc     5.1

# %%
# making name as index column
new_index=df['Name']
df=pd.DataFrame(data_frame)
df=df.set_index(new_index)
df.drop(columns='Name')
# Out:
#        Age   Address Qualification
# Name
# Sonia   27    Lahore           Msc
# Bilal   24   Karachi            MA
# Hifza   22   Sialkot           MCA
# Kabir   32  peshawar           Phd
# Jazim   23       lhr           bsc

# %%
# retrieve row with index “Hifza”
df.loc['Hifza']
# Out:
# Name               Hifza
# Age                   22
# Address          Sialkot
# Qualification        MCA
# Name: Hifza, dtype: object

# %%
# retrieve row with index “3”
df.iloc[3]
# Out:
# Name                Kabir
# Age                    32
# Address          peshawar
# Qualification         Phd
# Name: Kabir, dtype: object

# %%
df.drop(index='Bilal')
# Out:
#         Name  Age   Address Qualification
# Name
# Sonia  Sonia   27    Lahore           Msc
# Hifza  Hifza   22   Sialkot           MCA
# Kabir  Kabir   32  peshawar           Phd
# Jazim  Jazim   23       lhr           bsc
